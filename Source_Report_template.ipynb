# %% [markdown]
# #Source Report
#
# This is a report of the source...

# %% [markdown]
# ### Particle type

# %%
source.particle
# Out:
# 'unknown'

# %% [markdown]
# ### Spatial distribution

# %%
f, axarr = plt.subplots(1,3,sharey=True, figsize=(18,6));
axarr[0].hist(source.data['x'].magnitude);
axarr[0].locator_params(axis='x',nbins=7);
axarr[1].hist(source.data['y'].magnitude);
axarr[1].locator_params(axis='x',nbins=7);
axarr[2].hist(source.data['z'].magnitude);
axarr[2].locator_params(axis='x',nbins=7);

# %% [markdown]
# ### Momentum distribution

# %%
dircosines_surf(source);

# %% [markdown]
# ### Energy Distribution

# %%
plt.hist(source.data['E'].magnitude);

# %% [markdown]
# ---
#
# ### Initial commands for setup...
#
# ---

# %%
# %matplotlib inline

from sc_check import *

source_file = '/home/leonel/Dropbox/Work/PythonExamples/Source_Interface/sourcefiles_given/1200MeV-distribution.txt'

source = Source_File(source_file)

source.set_magnitudes(default_magnitudes)
source.set_units(default_units)

source.import_file(skip_header=5)
